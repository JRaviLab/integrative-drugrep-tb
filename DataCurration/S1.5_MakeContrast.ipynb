# %% [markdown]
# # Notebook 1.5
#
# **Author : Ling Thang**
#
# **Date : Oct 7 2025**
#
# ## Documentations and Code :
#
# Purpose : Updating metadata files to create contrast for each disease
#
# output : Concated MEGA metadata file with both manually currated features (ALL CAPS) and features from original metadata (lower case)
#
# ## Key Goal :
#
# Final metadata for each disease with CONTRAST column in addition to other relevant features
#
# relevant features : columns from GEO metadata that are consitent across all diseases
#
# __________
#
# ##### Libraries and Tools

# %%
# Python v3.11.12
import pandas as pd 
import os
from typing import Dict, Tuple

# %% [markdown]
# ##### Initialize paths and files

# %%
TB_metadata_path = '../data/metadata/TB'

# read manual labeling
TBlabels =	pd.read_csv("../labeling/TB/TB_manCleaned.tsv", sep = "\t")

# %% [markdown]
# # General EDA

# %% [markdown]
# ### Ensure column consistency and extract relevant columns

# %% [markdown]
# ### Get list of Series

# %%
print(TBlabels.shape)
print(TBlabels["GSE_ID"].unique(), TBlabels["GSE_ID"].nunique())
TBlabels.isnull().sum()
# Out:
# (520, 9)
# ['GSE84076' 'GSE148171' 'GSE198557' 'GSE112482' 'GSE112483' 'GSE132283'
#  'GSE143627' 'GSE148731' 'GSE174566' 'GSE193777' 'GSE223863' 'GSE256184'
#  'GSE64179' 'GSE64182' 'GSE121049' 'GSE141656' 'GSE143731' 'GSE164287'
#  'GSE165708' 'GSE183912' 'GSE211974' 'GSE236156'] 22
# GSE_ID                           0
# GSM_ID                           0
# CLASSIFICATION_STANDARDIZED      0
# SAMPLE_TYPE                      0
# CELL_SOURCE_CLEAN                0
# TISSUE_SOURCE_CLEAN              0
# CL:CODE                          0
# UBERON:CODE                      0
# CONTEXT                        438
# dtype: int64

# %% [markdown]
# # CONCAT GEO metadata with manual labeling
#
# creating final metadata data file for each disease (FINAL_METADATA_{DISEASE}.tsv)
#
# ##### General Functions
# _______

# %%
# used in previous interations to identify cols_to_extract -- columns that are informational and columns across all metadata files
def extract_cols_with_counts(path):
	"""
	Extracts all unique column names from files in a directory and counts in how many files each column appears.
	Returns a dictionary {column_name: count}.
	"""
	col_counts = {}
	for filename in os.listdir(path):
		file_path = os.path.join(path, filename)
		if os.path.isfile(file_path):
			df = pd.read_csv(file_path, sep='\t')
			for col in set(df.columns):
				col_counts[col] = col_counts.get(col, 0) + 1
	return col_counts

# %%
def create_mega_df_from_dir(metadata_path, labeled_df, cols_of_interest, use_NA_string=False):
    """
    Iterates over all files in Metadata Path, extracts cols_of_interest, 
    keeps only rows with series_id and geo_accession in labeled_df,
    and returns the combined DataFrame.
    Missing columns are filled with 'NA' if use_NA_string is True, otherwise left as NaN.
    """
    mega_df = [] # MEGA DF 
    valid_gse = set(labeled_df['GSE_ID']) # identified Series and that passed manual labeling
    valid_gsm = set(labeled_df['GSM_ID']) # identified Samples and that passed manual labeling

    for fname in os.listdir(metadata_path): # iterate through all files in metadata directory
        if fname.endswith('.tsv'):
            fpath = os.path.join(metadata_path, fname)
            df = pd.read_csv(fpath, sep='\t') # loads as pd DataFrame
            # Ensure all columns of interest are present, fill missing with NaN
            df = df.reindex(columns=cols_of_interest)
            # Filter rows
            if 'series_id' in df.columns and 'geo_accession' in df.columns:
                df = df[df['series_id'].isin(valid_gse) & df['geo_accession'].isin(valid_gsm)] # keep only rows with series_id and geo_accession in labeled_df
                mega_df.append(df) # append to list
    if mega_df: # if list is not empty
        mega_df = pd.concat(mega_df, ignore_index=True)
        if use_NA_string:
            mega_df = mega_df.fillna(pd.NA) # fill missing values with 'NA' string
        return mega_df
    else:
        print("No data found matching criteria.") 
        return pd.DataFrame(columns=cols_of_interest) # return empty if no data found

# %% [markdown]
# _______

# %% [markdown]
# ## Variables and Functions for this section
#
# ```python
# # defined in the begining of the notebook
# TB_metadata_path = '../data/metadata/TB'
# ```

# %%
# Columns of interest to extract from metadata files
cols_to_extract = [
	'series_id',
	'geo_accession',
	'title',
	'source_name_ch1',
	'organism_ch1',
	'characteristics_ch1',
	'characteristics_ch1.1',
	'characteristics_ch1.2',
	'characteristics_ch1.3',
	'molecule_ch1',
	'platform_id',
	'library_source',
	'library_strategy',
	'cell type:ch1',
	'tissue:ch1',
	'time:ch1',
	'time point:ch1',
]

# %%
# Final columns to keep in the merged dataframe -- Combined with labeling COLS
FINALCOLS = [
	'title',
	'organism_ch1',
	'GSE_ID', 
	'series_id',
	'GSM_ID',
	'geo_accession',
	'CLASSIFICATION_STANDARDIZED',
	'SAMPLE_TYPE',
	'source_name_ch1',
	'CELL_SOURCE_CLEAN',
	'cell type:ch1',
	'CL:CODE',
	'tissue:ch1',
	'TISSUE_SOURCE_CLEAN',
    'UBERON:CODE',
	'CONTEXT',
	'time point:ch1',
	'time:ch1', 
	'characteristics_ch1',
	'characteristics_ch1.1',
	'characteristics_ch1.2',
	'characteristics_ch1.3',
	'molecule_ch1',
	'platform_id',
	'library_source',
	'library_strategy',
	'treatment'
]

# %%
def merge_labels_and_metadata(labels_df, mega_df):
	"""
	mega_df - output of create_mega_df_from_dir() function

	Merge labeled metadata and MEGA metadata dataframes on series_id/GSE_ID and geo_accession/GSM_ID.
	Ensures the resulting columns are ordered according to columns_list.
	"""
	merged = pd.merge( # merge on GSE_ID/series_id and GSM_ID/geo_accession
		labels_df, # left 
		mega_df, # right
		left_on=['GSE_ID', 'GSM_ID'], # features on the left dataframe
		right_on=['series_id', 'geo_accession'], # features on the right dataframe
		how='inner' # inner join to keep only rows with matches in both dataframes
	)
	# Only keep columns present in FINALCOLS and order them
	merged = merged[[col for col in FINALCOLS if col in merged.columns]]
	# Only return if GSE_ID == series_id and GSM_ID == geo_accession
	if not merged['GSE_ID'].equals(merged['series_id']):
		raise ValueError("GSE_ID and series_id columns do not match exactly.") # prevents GSE inconsistencies
	if not merged['GSM_ID'].equals(merged['geo_accession']):
		raise ValueError("GSM_ID and geo_accession columns do not match exactly.") # prevents GSM inconsistencies
	if merged['GSE_ID'].equals(merged['series_id']) and merged['GSM_ID'].equals(merged['geo_accession']):
		# drop duplicate columns
		merged = merged.drop(columns=['GSE_ID', 'GSM_ID']) # only keep series_id and geo_accession from GEO
		print("Merge successful")
	return merged # only returns if both columns match exactly

# %% [markdown]
# ______
# ## TB

# %%
TBmeta = create_mega_df_from_dir(TB_metadata_path, TBlabels, cols_to_extract, use_NA_string=True)

# %%
TBmeta.shape
# Out:
# (520, 17)

# %%
TBlabels.shape
# Out:
# (520, 9)

# %% [markdown]
# Rows (samples count) are expected to match

# %% [markdown]
# ### merge metadata with signature data

# %%
TBmeta
# Out:
#      series_id geo_accession                 title  \
# 0    GSE236156    GSM7518958         AM10_AM_Media
# 1    GSE236156    GSM7518959            AM10_AM_TB
# 2    GSE236156    GSM7518960        AM10_MDM_Media
# 3    GSE236156    GSM7518961           AM10_MDM_TB
# 4    GSE236156    GSM7518962         AM12_AM_Media
# ..         ...           ...                   ...
# 515  GSE198557    GSM5952187  Healthy indivudual_2
# 516  GSE198557    GSM5952188  Healthy indivudual_3
# 517  GSE198557    GSM5952189  Healthy indivudual_4
# 518  GSE198557    GSM5952190  Healthy indivudual_5
# 519  GSE198557    GSM5952191  Healthy indivudual_6
#
#                              source_name_ch1  organism_ch1  \
# 0                     bronchoalveolar lavage  Homo sapiens
# 1                     bronchoalveolar lavage  Homo sapiens
# 2                                      blood  Homo sapiens
# 3                                      blood  Homo sapiens
# 4                     bronchoalveolar lavage  Homo sapiens
# ..                                       ...           ...
# 515  PBMCs isolated from Healthy individuals  Homo sapiens
# 516  PBMCs isolated from Healthy individuals  Homo sapiens
# 517  PBMCs isolated from Healthy individuals  Homo sapiens
# 518  PBMCs isolated from Healthy individuals  Homo sapiens
# 519  PBMCs isolated from Healthy individuals  Homo sapiens
#
#                     characteristics_ch1  \
# 0        tissue: bronchoalveolar lavage
# 1        tissue: bronchoalveolar lavage
# 2                         tissue: blood
# 3                         tissue: blood
# 4        tissue: bronchoalveolar lavage
# ..                                  ...
# 515  subject status: Healthy individual
# 516  subject status: Healthy individual
# 517  subject status: Healthy individual
# 518  subject status: Healthy individual
# 519  subject status: Healthy individual
#
#                       characteristics_ch1.1             characteristics_ch1.2  \
# 0            cell type: alveolar macrophage                  treatment: Media
# 1            cell type: alveolar macrophage        treatment: M. tuberculosis
# 2    cell type: monocyte-derived macrophage                  treatment: Media
# 3    cell type: monocyte-derived macrophage        treatment: M. tuberculosis
# 4            cell type: alveolar macrophage                  treatment: Media
# ..                                      ...                               ...
# 515                        cell type: PBMCs  molecule type: rRNA-depleted RNA
# 516                        cell type: PBMCs  molecule type: rRNA-depleted RNA
# 517                        cell type: PBMCs  molecule type: rRNA-depleted RNA
# 518                        cell type: PBMCs  molecule type: rRNA-depleted RNA
# 519                        cell type: PBMCs  molecule type: rRNA-depleted RNA
#
#     characteristics_ch1.3 molecule_ch1 platform_id  library_source  \
# 0       treatment2: Fresh    total RNA    GPL24676  transcriptomic
# 1       treatment2: Fresh    total RNA    GPL24676  transcriptomic
# 2      treatment2: Frozen    total RNA    GPL24676  transcriptomic
# 3      treatment2: Frozen    total RNA    GPL24676  transcriptomic
# 4       treatment2: Fresh    total RNA    GPL24676  transcriptomic
# ..                    ...          ...         ...             ...
# 515                  <NA>    total RNA    GPL16791  transcriptomic
# 516                  <NA>    total RNA    GPL16791  transcriptomic
# 517                  <NA>    total RNA    GPL16791  transcriptomic
# 518                  <NA>    total RNA    GPL16791  transcriptomic
# 519                  <NA>    total RNA    GPL16791  transcriptomic
#
#     library_strategy                cell type:ch1              tissue:ch1  \
# 0            RNA-Seq          alveolar macrophage  bronchoalveolar lavage
# 1            RNA-Seq          alveolar macrophage  bronchoalveolar lavage
# 2            RNA-Seq  monocyte-derived macrophage                   blood
# 3            RNA-Seq  monocyte-derived macrophage                   blood
# 4            RNA-Seq          alveolar macrophage  bronchoalveolar lavage
# ..               ...                          ...                     ...
# 515          RNA-Seq                        PBMCs                    <NA>
# 516          RNA-Seq                        PBMCs                    <NA>
# 517          RNA-Seq                        PBMCs                    <NA>
# 518          RNA-Seq                        PBMCs                    <NA>
# 519          RNA-Seq                        PBMCs                    <NA>
#
#     time:ch1 time point:ch1
# 0       <NA>           <NA>
# 1       <NA>           <NA>
# 2       <NA>           <NA>
# 3       <NA>           <NA>
# 4       <NA>           <NA>
# ..       ...            ...
# 515     <NA>           <NA>
# 516     <NA>           <NA>
# 517     <NA>           <NA>
# 518     <NA>           <NA>
# 519     <NA>           <NA>
#
# [520 rows x 17 columns]

# %%
TBlabels
# Out:
#         GSE_ID      GSM_ID        CLASSIFICATION_STANDARDIZED     SAMPLE_TYPE  \
# 0     GSE84076  GSM2226808  Healthy Control without treatment    blood_sample
# 1     GSE84076  GSM2226809          Disease without treatment    blood_sample
# 2     GSE84076  GSM2226817          Disease without treatment    blood_sample
# 3     GSE84076  GSM2226825  Healthy Control without treatment    blood_sample
# 4     GSE84076  GSM2226829  Healthy Control without treatment    blood_sample
# ..         ...         ...                                ...             ...
# 515  GSE236156  GSM7519008          Disease without treatment  primary_sample
# 516  GSE236156  GSM7519009  Healthy Control without treatment  primary_sample
# 517  GSE236156  GSM7519010  Healthy Control without treatment  primary_sample
# 518  GSE236156  GSM7519011          Disease without treatment  primary_sample
# 519  GSE236156  GSM7519012          Disease without treatment  primary_sample
#
#           CELL_SOURCE_CLEAN TISSUE_SOURCE_CLEAN     CL:CODE     UBERON:CODE  \
# 0               Blood Cells               Blood  CL:0000081  UBERON:0000178
# 1               Blood Cells               Blood  CL:0000081  UBERON:0000178
# 2               Blood Cells               Blood  CL:0000081  UBERON:0000178
# 3               Blood Cells               Blood  CL:0000081  UBERON:0000178
# 4               Blood Cells               Blood  CL:0000081  UBERON:0000178
# ..                      ...                 ...         ...             ...
# 515  bronchoalveolar lavage                BALF        BALF            BALF
# 516  bronchoalveolar lavage                BALF        BALF            BALF
# 517  bronchoalveolar lavage                BALF        BALF            BALF
# 518  bronchoalveolar lavage                BALF        BALF            BALF
# 519  bronchoalveolar lavage                BALF        BALF            BALF
#
#     CONTEXT
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# ..      ...
# 515     NaN
# 516     NaN
# 517     NaN
# 518     NaN
# 519     NaN
#
# [520 rows x 9 columns]

# %%
TBfinal = merge_labels_and_metadata(TBlabels, TBmeta)
# Out:
# Merge successful

# %%
TBfinal.shape
# Out:
# (520, 24)

# %%
TBfinal
# Out:
#                    title  organism_ch1  series_id geo_accession  \
# 0           Ctrl_Unvac_3  Homo sapiens   GSE84076    GSM2226808
# 1                  ATB_5  Homo sapiens   GSE84076    GSM2226809
# 2                  ATB_4  Homo sapiens   GSE84076    GSM2226817
# 3           Ctrl_Unvac_2  Homo sapiens   GSE84076    GSM2226825
# 4           Ctrl_Unvac_1  Homo sapiens   GSE84076    GSM2226829
# ..                   ...           ...        ...           ...
# 515      AM18_AM_TB_Cryo  Homo sapiens  GSE236156    GSM7519008
# 516   AM21_AM_Media_Cryo  Homo sapiens  GSE236156    GSM7519009
# 517  AM21_AM_Media_Fresh  Homo sapiens  GSE236156    GSM7519010
# 518      AM21_AM_TB_Cryo  Homo sapiens  GSE236156    GSM7519011
# 519     AM21_AM_TB_Fresh  Homo sapiens  GSE236156    GSM7519012
#
#            CLASSIFICATION_STANDARDIZED     SAMPLE_TYPE  \
# 0    Healthy Control without treatment    blood_sample
# 1            Disease without treatment    blood_sample
# 2            Disease without treatment    blood_sample
# 3    Healthy Control without treatment    blood_sample
# 4    Healthy Control without treatment    blood_sample
# ..                                 ...             ...
# 515          Disease without treatment  primary_sample
# 516  Healthy Control without treatment  primary_sample
# 517  Healthy Control without treatment  primary_sample
# 518          Disease without treatment  primary_sample
# 519          Disease without treatment  primary_sample
#
#             source_name_ch1       CELL_SOURCE_CLEAN        cell type:ch1  \
# 0               Whole blood             Blood Cells                 <NA>
# 1               Whole blood             Blood Cells                 <NA>
# 2               Whole blood             Blood Cells                 <NA>
# 3               Whole blood             Blood Cells                 <NA>
# 4               Whole blood             Blood Cells                 <NA>
# ..                      ...                     ...                  ...
# 515  bronchoalveolar lavage  bronchoalveolar lavage  alveolar macrophage
# 516  bronchoalveolar lavage  bronchoalveolar lavage  alveolar macrophage
# 517  bronchoalveolar lavage  bronchoalveolar lavage  alveolar macrophage
# 518  bronchoalveolar lavage  bronchoalveolar lavage  alveolar macrophage
# 519  bronchoalveolar lavage  bronchoalveolar lavage  alveolar macrophage
#
#         CL:CODE  ... time point:ch1 time:ch1  \
# 0    CL:0000081  ...           <NA>     <NA>
# 1    CL:0000081  ...           <NA>     <NA>
# 2    CL:0000081  ...           <NA>     <NA>
# 3    CL:0000081  ...           <NA>     <NA>
# 4    CL:0000081  ...           <NA>     <NA>
# ..          ...  ...            ...      ...
# 515        BALF  ...           <NA>     <NA>
# 516        BALF  ...           <NA>     <NA>
# 517        BALF  ...           <NA>     <NA>
# 518        BALF  ...           <NA>     <NA>
# 519        BALF  ...           <NA>     <NA>
#
#                                    characteristics_ch1  \
# 0    clinical information: Control - BCG - Unvaccin...
# 1            clinical information: Active Tuberculosis
# 2            clinical information: Active Tuberculosis
# 3    clinical information: Control - BCG - Unvaccin...
# 4    clinical information: Control - BCG - Unvaccin...
# ..                                                 ...
# 515                     tissue: bronchoalveolar lavage
# 516                     tissue: bronchoalveolar lavage
# 517                     tissue: bronchoalveolar lavage
# 518                     tissue: bronchoalveolar lavage
# 519                     tissue: bronchoalveolar lavage
#
#               characteristics_ch1.1       characteristics_ch1.2  \
# 0               tissue: whole blood                        <NA>
# 1               tissue: whole blood                        <NA>
# 2               tissue: whole blood                        <NA>
# 3               tissue: whole blood                        <NA>
# 4               tissue: whole blood                        <NA>
# ..                              ...                         ...
# 515  cell type: alveolar macrophage  treatment: M. tuberculosis
# 516  cell type: alveolar macrophage            treatment: Media
# 517  cell type: alveolar macrophage            treatment: Media
# 518  cell type: alveolar macrophage  treatment: M. tuberculosis
# 519  cell type: alveolar macrophage  treatment: M. tuberculosis
#
#     characteristics_ch1.3 molecule_ch1 platform_id  library_source  \
# 0                    <NA>    polyA RNA    GPL16791  transcriptomic
# 1                    <NA>    polyA RNA    GPL16791  transcriptomic
# 2                    <NA>    polyA RNA    GPL16791  transcriptomic
# 3                    <NA>    polyA RNA    GPL16791  transcriptomic
# 4                    <NA>    polyA RNA    GPL16791  transcriptomic
# ..                    ...          ...         ...             ...
# 515    treatment2: Frozen    total RNA    GPL24676  transcriptomic
# 516    treatment2: Frozen    total RNA    GPL24676  transcriptomic
# 517     treatment2: Fresh    total RNA    GPL24676  transcriptomic
# 518    treatment2: Frozen    total RNA    GPL24676  transcriptomic
# 519     treatment2: Fresh    total RNA    GPL24676  transcriptomic
#
#     library_strategy
# 0            RNA-Seq
# 1            RNA-Seq
# 2            RNA-Seq
# 3            RNA-Seq
# 4            RNA-Seq
# ..               ...
# 515          RNA-Seq
# 516          RNA-Seq
# 517          RNA-Seq
# 518          RNA-Seq
# 519          RNA-Seq
#
# [520 rows x 24 columns]

# %% [markdown]
# ____
# ## Final Check
# ____

# %%
# Check to make sure that the shapes for labels, meta, and final are the same
print("TB Row Check:", TBlabels.shape[0] == TBmeta.shape[0] == TBfinal.shape[0])

print("\n")

# + 2 to account for dropping GSE_ID and GSM_ID columns
print("TB Column Check:", TBlabels.shape[1] + TBmeta.shape[1] == (TBfinal.shape[1]+2))
# Out:
# TB Row Check: True
# AST Row Check: True
# CF Row Check: True
# IPF Row Check: True
# COPD Row Check: True
#
#
# TB Column Check: True
# AST Column Check: True
# CF Column Check: True
# IPF Column Check: True
# COPD Column Check: True

# %% [markdown]
# all true as we are expecting the rows to stay consistent and columns to add up (excluding the duplicate features)

# %% [markdown]
# **Success of merge_signature_and_metadata() function means that Series (GSE_ID) and Sample (GSM_ID) columns match exactly between metadata and signature data for each disease.**

# %%
# save final MEGA dfs
TBfinal.to_csv("../data/FINALMETA/TB_FINAL.tsv", sep = "\t", index = False)
ASTfinal.to_csv("../data/FINALMETA/AST_FINAL.tsv", sep = "\t", index = False)
CFfinal.to_csv("../data/FINALMETA/CF_FINAL.tsv", sep = "\t", index = False)
IPFfinal.to_csv("../data/FINALMETA/IPF_FINAL.tsv", sep = "\t", index = False)
COPDfinal.to_csv("../data/FINALMETA/COPD_FINAL.tsv", sep = "\t", index = False)

# %% [markdown]
# # Make Contrasts
#
# Variables for this section
#
# ```python
# # Final DFs created above
# TBfinal
# ASTfinal
# CFfinal
# IPFfinal
# COPDfinal
# ```

# %%
print(list(TBfinal.columns) == list(ASTfinal.columns) == list(CFfinal.columns) == list(IPFfinal.columns) == list(COPDfinal.columns))

print("Final columns:", TBfinal.columns)
# Out:
# True
# Final columns: Index(['title', 'organism_ch1', 'series_id', 'geo_accession',
#        'CLASSIFICATION_STANDARDIZED', 'SAMPLE_TYPE', 'source_name_ch1',
#        'CELL_SOURCE_CLEAN', 'cell type:ch1', 'CL:CODE', 'tissue:ch1',
#        'TISSUE_SOURCE_CLEAN', 'UBERON:CODE', 'CONTEXT', 'time point:ch1',
#        'time:ch1', 'characteristics_ch1', 'characteristics_ch1.1',
#        'characteristics_ch1.2', 'characteristics_ch1.3', 'molecule_ch1',
#        'platform_id', 'library_source', 'library_strategy'],
#       dtype='object')

# %%
# make sure that all the Classification Standardized are either "Healthy" or "Disease"
print(f"TBfinal classification check: ", set(TBfinal["CLASSIFICATION_STANDARDIZED"].unique()).issubset({"Healthy Control without treatment", "Disease without treatment"}))
# Out:
# TBfinal classification check:  True
# ASTfinal classification check:  True
# CFfinal classification check:  True
# IPFfinal classification check:  True
# COPDfinal classification check:  True

# %% [markdown]
# ## Get Contrast Function

# %%
def get_detailed_contrasts(metadata_df: pd.DataFrame, disease_name: str) -> pd.DataFrame:
    """
    Identifies all valid DGE contrasts (>=3 Disease vs >=3 Healthy) and prints 
    the list of contrasts that failed the criteria and why.

    Args:
        metadata_df: The final merged DataFrame for a single disease.
        disease_name: The name of the disease.

    Returns:
        valid_samples_df: DataFrame of samples belonging to valid contrasts.
    """
    # Define required grouping keys and group names
    group_cols = ['series_id', 'CL:CODE', 'UBERON:CODE', 'CONTEXT'] 
    D_name = 'Disease without treatment'
    H_name = 'Healthy Control without treatment'
    MIN_SAMPLES = 3

    metadata_df = metadata_df.copy()
    metadata_df['CONTEXT'] = metadata_df['CONTEXT'].fillna('NoCONTEXT') # Fill NA context for grouping
    
    # Keep only samples designated for DGE comparison
    dge_eligible_df = metadata_df[metadata_df['CLASSIFICATION_STANDARDIZED'].isin([D_name, H_name])]
    
    # Count samples for each unique biological context/potential contrast
    grouped_counts = dge_eligible_df.groupby(group_cols + ['CLASSIFICATION_STANDARDIZED'])['geo_accession'].count().reset_index()
    grouped_counts = grouped_counts.rename(columns={'geo_accession': 'Count'})

    # Pivot to get Disease and Healthy counts side-by-side for comparison
    contrast_counts = grouped_counts.pivot_table(
        index=group_cols, 
        columns='CLASSIFICATION_STANDARDIZED', 
        values='Count', 
        fill_value=0
    ).reset_index()
    
    # Keep contrasts that meet the >= 3 samples in both groups rule
    valid_contrasts = contrast_counts[
        (contrast_counts[D_name] >= MIN_SAMPLES) & 
        (contrast_counts[H_name] >= MIN_SAMPLES)
    ].copy()
    
    # Identify contrasts that failed the rule
    failed_contrasts = contrast_counts[
        ~((contrast_counts[D_name] >= MIN_SAMPLES) & (contrast_counts[H_name] >= MIN_SAMPLES))
    ].copy()
    
    # Print the specific reason for failure for each discarded contrast
    if not failed_contrasts.empty:
        print("\nContrasts That Failed to meet DESEQ Criteria: ")
        for _, row in failed_contrasts.iterrows():
            contrast_name = f"{row['series_id']}_{row['CL:CODE']}_{row['UBERON:CODE']}_{row['CONTEXT']}"
            d_count, h_count = int(row[D_name]), int(row[H_name])
            reason = ""
            
            if d_count < MIN_SAMPLES and h_count < MIN_SAMPLES:
                reason = f"{d_count} Disease & {h_count} Healthy samples"
            elif d_count < MIN_SAMPLES:
                reason = f"{d_count} Disease samples for the contrast"
            elif h_count < MIN_SAMPLES:
                reason = f"{h_count} Healthy samples for the contrast"

            print(f"{contrast_name} - {reason}")

    # Rename count columns and create the unique Contrast ID string
    valid_contrasts.rename(columns={D_name: 'N_Disease', H_name: 'N_Healthy'}, inplace=True)
    valid_contrasts['CONTRAST'] = valid_contrasts.apply(
        lambda row: f"{row['series_id']}_{row['CL:CODE']}_{row['UBERON:CODE']}_{row['CONTEXT']}", axis=1
    )
    
    # Get the key identifiers of the valid contrasts
    valid_keys = [tuple(x) for x in valid_contrasts[group_cols].values]

    # Filter original eligible samples to keep only those in valid contrasts
    valid_samples_df = dge_eligible_df[dge_eligible_df.set_index(group_cols).index.isin(valid_keys)].copy()
    
    # Attach the new CONTRAST ID and final sample counts
    valid_samples_df = pd.merge(
        valid_samples_df, 
        valid_contrasts[group_cols + ['CONTRAST', 'N_Disease', 'N_Healthy']], 
        on=group_cols, 
        how='left'
    )

    # Define the path for the expression matrix based on series_id
    valid_samples_df['EXPRMAT_PATH'] = valid_samples_df['series_id'].apply(
        lambda x: f"data/FinalExpression/{disease_name}/{x}.tsv"
    )

    # RENAME CLASSIFICATION_STANDARDIZED to CLASSIFICATION
    valid_samples_df.rename(columns={'CLASSIFICATION_STANDARDIZED': 'CLASSIFICATION'}, inplace=True)

    # Select and reorder final columns for output
    final_cols_order = [
        'series_id', 'geo_accession', 'CLASSIFICATION', 
        'CONTRAST', 'EXPRMAT_PATH'
    ]
    
    return valid_samples_df[final_cols_order].reset_index(drop=True)

# %% [markdown]
# ## TB

# %%
TB_DGE_df = get_detailed_contrasts(TBfinal, 'TB')

# %%
TB_DGE_df
# Out:
#      series_id geo_accession                     CLASSIFICATION  \
# 0     GSE84076    GSM2226808  Healthy Control without treatment
# 1     GSE84076    GSM2226809          Disease without treatment
# 2     GSE84076    GSM2226817          Disease without treatment
# 3     GSE84076    GSM2226825  Healthy Control without treatment
# 4     GSE84076    GSM2226829  Healthy Control without treatment
# ..         ...           ...                                ...
# 515  GSE236156    GSM7519008          Disease without treatment
# 516  GSE236156    GSM7519009  Healthy Control without treatment
# 517  GSE236156    GSM7519010  Healthy Control without treatment
# 518  GSE236156    GSM7519011          Disease without treatment
# 519  GSE236156    GSM7519012          Disease without treatment
#
#                                          CONTRAST  \
# 0    GSE84076_CL:0000081_UBERON:0000178_NoCONTEXT
# 1    GSE84076_CL:0000081_UBERON:0000178_NoCONTEXT
# 2    GSE84076_CL:0000081_UBERON:0000178_NoCONTEXT
# 3    GSE84076_CL:0000081_UBERON:0000178_NoCONTEXT
# 4    GSE84076_CL:0000081_UBERON:0000178_NoCONTEXT
# ..                                            ...
# 515                 GSE236156_BALF_BALF_NoCONTEXT
# 516                 GSE236156_BALF_BALF_NoCONTEXT
# 517                 GSE236156_BALF_BALF_NoCONTEXT
# 518                 GSE236156_BALF_BALF_NoCONTEXT
# 519                 GSE236156_BALF_BALF_NoCONTEXT
#
#                               EXPRMAT_PATH
# 0     data/FinalExpression/TB/GSE84076.tsv
# 1     data/FinalExpression/TB/GSE84076.tsv
# 2     data/FinalExpression/TB/GSE84076.tsv
# 3     data/FinalExpression/TB/GSE84076.tsv
# 4     data/FinalExpression/TB/GSE84076.tsv
# ..                                     ...
# 515  data/FinalExpression/TB/GSE236156.tsv
# 516  data/FinalExpression/TB/GSE236156.tsv
# 517  data/FinalExpression/TB/GSE236156.tsv
# 518  data/FinalExpression/TB/GSE236156.tsv
# 519  data/FinalExpression/TB/GSE236156.tsv
#
# [520 rows x 5 columns]

# %% [markdown]
# ## Check the outputs

# %%
# standardize the contrast columns delete : and spaces
TB_DGE_df['CONTRAST'] = TB_DGE_df['CONTRAST'].str.replace(':', '', regex=False).str.replace(' ', '', regex=False)

# %%
# save all DGE dfs
TB_DGE_df.to_csv("../dge/DGEinputs/TB_DGE_inputs.tsv", sep = "\t", index = False)

# %%
# Check to make sure that the shapes for labels, meta, and final are the same
print(f"TB samples loss check :", TB_DGE_df.shape[0] - TBfinal.shape[0])
# Out:
# TB samples loss check : 0
# AST samples loss check : 0
# CF samples loss check : 0
# IPF samples loss check : 0
# COPD samples loss check : -32
